# %% [markdown]
# <a href="https://colab.research.google.com/github/divyansh-ag-03/RL-21CSU214/blob/main/Experiment_2_Part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
x = np.random.randint(0,50,1000)

# %%
# !x
# Out:
# /bin/bash: line 1: x: command not found

# %%
y = x + np.random.normal(0,10,1000)

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.81084899],
#        [0.81084899, 1.        ]])

# %%
plt.style.use('ggplot')

# %%
plt.scatter(x,y)

# %% [markdown]
# Positive Correlation between X and Y, Showing linear scatter plot.

# %%
y = 100 -(x + np.random.normal(0,10,1000))

# %%
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.81604338],
#        [-0.81604338,  1.        ]])

# %%
plt.style.use('ggplot')
plt.scatter(x,y)

# %% [markdown]
# Negative Correlation between X and Y, Showing linear scatter plot.

# %%
x = np.random.randint(0,50,1000)

# %%
y = np.random.randint(0,10,1000)

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.02838702],
#        [0.02838702, 1.        ]])

# %%
plt.scatter(x,y)

# %%
df = pd.DataFrame({'a': np.random.randint(0,50,1000)})
df['b'] = df['a'] + np.random.randint(0,10,1000)
df['c'] = 100 - df['a'] + np.random.normal(0,5,1000)
df['d'] = np.random.randint(0,50,1000)

df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.981204 -0.943851 -0.032926
# b  0.981204  1.000000 -0.930964 -0.030609
# c -0.943851 -0.930964  1.000000  0.025019
# d -0.032926 -0.030609  0.025019  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize = (12,12))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()
